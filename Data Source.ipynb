# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.set_printoptions(suppress=True)
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing datasets
Main = pd.read_csv('Datasource.csv')

# %%
Main.head()
# Out:
#             TrialID Last Refreshed on  \
# 0  ChiCTR2400089575         16-Sep-24
# 1  ChiCTR2400089593         16-Sep-24
# 2  ChiCTR2400089613         16-Sep-24
# 3       RBR-22k3fm7         16-Sep-24
# 4     RPCEC00000450         16-Sep-24
#
#                                         Public title  \
# 0  Analysis of surgical risk factors in patients ...
# 1  Effects of COVID-19 on male reproductive function
# 2  Success factors for improving prognosis by awa...
# 3  Effects of Stimulation of the Auricular Branch...
# 4  Evaluation of the effect and safety of a boost...
#
#                                     Scientific title Acronym  \
# 0  Analysis of surgical risk factors in patients ...     NaN
# 1  Effects of COVID-19 on male reproductive funct...     NaN
# 2  Success factors for improving prognosis by awa...     NaN
# 3  Effects of Stimulation of the Auricular Branch...     NaN
# 4  Evaluation of the effect and safety of a boost...     NaN
#
# ...
